# %% [markdown]
# <a href="https://colab.research.google.com/github/AdvikaDG/myPythonLearning/blob/main/PythonCoding2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2021-05-29 163721.jpg](data:image/jpeg;base64,...)

# %%
my_gpa =3.47
type(my_gpa)
# Out:
# float

# %%
my_score=300
type(my_score)
# Out:
# int

# %%
a=6
b=3
a+b
# Out:
# 9

# %%
a-b
# Out:
# 3

# %%
a*b
# Out:
# 18

# %%
a/b
# Out:
# 2.0

# %%
a%b
# Out:
# 0

# %%
a//b
# Out:
# 2

# %%
a**b
# Out:
# 216
